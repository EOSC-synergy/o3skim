# %% [markdown]
# # Reducing longitude coordinate in models

# %% [markdown]
# The main objective of o3skim library is to reduce model size in order to provide ozone data for optimal trends analysis and transference. In order to accomplish with this target, the library offers a `lon_mean` method to calculate the **Zonal Means** of a dataset.

# %% [markdown]
# ### Zonal and meridional trends in Ozone analytics

# %% [markdown]
# **Zonal** and **meridional** regions of the Earth that follow
# a pattern along latitudinal lines (latitudinal circles in the west–east direction)
# or
# along the Earth's longitude lines (longitudinal circles in the north–south direction).
# These terms are often used in the atmospheric and earth sciences to describe global phenomena, such as `meridional wind` or `zonal average temperature`.
#
# In the case of Ozone trends the term **Zonal Mean** refers to the average of an ozone measurement across the latitudinal circles. This allows to reduce the size of datasets but maintaining representative information, for example to analyze the ozone concentration trends on the Arctic and Antarctic regions.

# %% [markdown]
# <p align="center">
# <img style="float: left; padding: 15px" src="../_static/Zonal_band.svg" width="250">
# <br>
#
# By Zonal_band.gif: created by NASAGlobe_Atlantic.svg
# U.S. Governmentderivative work: Rehua (talk)
# This file was derived from:Zonal band.gif:Globe Atlantic.svg
# [Public Domain](https://commons.wikimedia.org/w/index.php?curid=18137320)
# </p>

# %% [markdown]
# ### How to use o3skim.load_zmo3
# After importing o3skim as any normal Python module, you can simply call for `o3skim.lon_mean` function using the following arguments:
#
# - dataset: A multi-dimensional, in memory, Ozone model. See [load tco3 models](load_tco3.ipynb) and [load zmo3 models](load_zmo3.ipynb) for more details on how to load models.

# %%
import o3skim

model_paths = "tests/datasets_tco3/ECMWF_C3S_ERA5/*.nc"
dataset = o3skim.load_tco3(model_paths, model="ECMWF_C3S_ERA5")
o3skim.lon_mean(dataset)
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 81, time: 176)
# Coordinates:
#   * lat      (lat) float32 90.0 87.75 85.5 83.25 ... -83.25 -85.5 -87.75 -90.0
#   * time     (time) datetime64[ns] 1980-01-01 ... 1980-12-28T12:00:00
# Data variables:
#     tco3     (time, lat) float32 dask.array<chunksize=(88, 81), meta=np.ndarray>
# Attributes:
#     Conventions:  CF-1.6
#     history:      2020-08-14 16:56:09 GMT by grib_to_netcdf-2.16.0: /opt/ecmw...
#     institution:  Copernicus Climate Change Service
#     source:
