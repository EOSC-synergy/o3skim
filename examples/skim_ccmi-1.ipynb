# %% [markdown]
# Configure logging if you want to print function steps at `stderr`.

# %%
import logging
logging.basicConfig(level="DEBUG")

# %% [markdown]
# Use `ccmi` *function* inside `loads` *submodule* to load a normalized xarray dataset.

# %%
from o3skim import loads
paths = "../tests/datasets/CCMI-1/CCMI-1_ACCESS-CCM/*.nc"
ds = loads.ccmi(paths)
ds
# Out:
# INFO:o3skim.loads:Loading CCMI-1 data from: ../tests/datasets/CCMI-1/CCMI-1_ACCESS-CCM/*.nc
# DEBUG:o3skim.loads:Variable 'equivalent_thickness_at_stp_of_atmosphere_ozone_content' loading
# /home/borja/miniconda3/envs/o3as/lib/python3.8/site-packages/cf_xarray/accessor.py:1530: UserWarning: Variables {'areacella'} not found in object but are referred to in the CF attributes.
#   warnings.warn(
# DEBUG:o3skim.loads:Renaming var 'equivalent_thickness_at_stp_of_atmosphere_ozone_content' to 'tco3'
# DEBUG:o3skim.loads:Removing unused coords from '['time', 'lat', 'lon', 'ccmi_year', 'ccmi_month', 'ccmi_day', 'ccmi_hour', 'ccmi_minute']'
# DEBUG:o3skim.loads:Loading time variable 'time'
# <xarray.Dataset>
# Dimensions:    (time: 16, bnds: 2, lat: 73, lon: 96)
# Coordinates:
#   * time       (time) object 1960-01-16 00:00:00 ... 1961-04-16 00:00:00
#   * lat        (lat) float64 -90.0 -87.5 -85.0 -82.5 ... 82.5 85.0 87.5 90.0
# ...

# %% [markdown]
# Use `lon_mean` or `lat_mean` *functions* inside `o3skim` to calculate `Zonal Mean` or `Meridional Mean`.

# %%
import o3skim
ds = o3skim.lon_mean(ds)
ds
# Out:
# DEBUG:o3skim:Calculating mean over model longitude
# <xarray.Dataset>
# Dimensions:    (time: 16, bnds: 2, lat: 73)
# Coordinates:
#   * time       (time) object 1960-01-16 00:00:00 ... 1961-04-16 00:00:00
#   * lat        (lat) float64 -90.0 -87.5 -85.0 -82.5 ... 82.5 85.0 87.5 90.0
# Dimensions without coordinates: bnds
# Data variables:
#     time_bnds  (time, bnds) object 1960-01-01 00:00:00 ... 1961-05-01 00:00:00
#     lat_bnds   (lat, bnds) float64 dask.array<chunksize=(73, 2), meta=np.ndarray>
#     tco3       (time, lat) float32 dask.array<chunksize=(16, 73), meta=np.ndarray>
# Attributes:
#     institution:  U. Melbourne (University of Melbourne, Melbourne, Australia...
#     source:       ACCESS-CCM 2011 atmosphere: HadGEM2 r2.0 N48L60; SSTs: HadG...
#     comment:      SSTs/sea ice non-interactive using HadGEM2-ES CMIP5 r1p1i1 ...
#     references:   Model described by Stone et al. (2016)(Atmos. Chem. Phys., ...
#     Conventions:  CF-1.4
# ...
